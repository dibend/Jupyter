# %% [markdown]
# <a href="https://colab.research.google.com/github/dibend/Colab/blob/main/Big_Tech_Option_Chains.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

import yfinance as yf
import pandas as pd

yf.pdr_override()

stocklist = ['AAPL', 'AMZN', 'GOOG', 'META', 'MSFT']
optionsX = pd.DataFrame()

for x in stocklist:
    tk = yf.Ticker(x)  
    exps = tk.options  #expiration dates
    try:
        for e in exps:
            opt = tk.option_chain(e)
            opt = pd.DataFrame().append(opt.calls).append(opt.puts)
            opt['expirationDate'] = e
            opt['Symbol'] = x
            optionsX = optionsX.append(opt, ignore_index=True)
    except:
        pass
optionsX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#             contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      AAPL230106C00050000 2022-12-30 20:49:16+00:00    50.0      79.35
# 1      AAPL230106C00055000 2022-12-30 20:25:27+00:00    55.0      73.95
# 2      AAPL230106C00060000 2022-12-30 20:26:27+00:00    60.0      69.00
# 3      AAPL230106C00065000 2022-12-29 19:33:48+00:00    65.0      65.01
# 4      AAPL230106C00070000 2022-12-29 19:33:48+00:00    70.0      60.00
# ...                    ...                       ...     ...        ...
# 12528  MSFT250117P00370000 2022-12-05 17:11:21+00:00   370.0     119.85
# 12529  MSFT250117P00380000 2022-12-29 18:04:49+00:00   380.0     140.10
# 12530  MSFT250117P00385000 2022-12-19 20:07:15+00:00   385.0     148.01
# 12531  MSFT250117P00390000 2022-12-12 20:15:08+00:00   390.0     139.05
# 12532  MSFT250117P00400000 2022-11-15 19:34:21+00:00   400.0     158.25
#
# ...
