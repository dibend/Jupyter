# %% [markdown]
# <a href="https://colab.research.google.com/github/dibend/Colab/blob/main/Monero_Mining_Payments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import matplotlib.pyplot as plt
from datetime import datetime

plt.style.use("bmh")
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200

url = "https://xmr.2miners.com/api/accounts/42L4oBG4UAMY5ngPesipqLF4CUd1HjHJ7Rjv7o4vuxnRAYyvS2WEpErNGHjt55JPBQ7ik752KZgbebhBW6SU2eCRN8ME1tw"

response = requests.get(url)

data = response.json()

amounts_and_timestamps = [(payment['amount'] / 1000000000000, datetime.fromtimestamp(payment['timestamp'])) for payment in data['payments']]

# Extract the amounts and timestamps into separate lists
amounts, timestamps = zip(*amounts_and_timestamps)

# Plot the amounts against the timestamps
plt.scatter(timestamps, amounts, c='orange', edgecolors='black')

# Add a title and labels to the axes
plt.title("Payment amounts over time")
plt.xlabel("Timestamp")
plt.ylabel("Amount")

# Show the plot
plt.show()
