# %% [markdown]
# <a href="https://colab.research.google.com/github/dibend/Colab/blob/main/Ethereum_Classic_Mining_Payments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import matplotlib.pyplot as plt
from datetime import datetime

plt.style.use("bmh")
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200

url = "https://etc.2miners.com/api/accounts/0x3674b0c17defe6d23346601a037dee2e683c9cdc"

response = requests.get(url)

data = response.json()

amounts_and_timestamps = [(payment['amount'] / 1000000000, datetime.fromtimestamp(payment['timestamp'])) for payment in data['payments']]

# Extract the amounts and timestamps into separate lists
amounts, timestamps = zip(*amounts_and_timestamps)

# Plot the amounts against the timestamps
plt.scatter(timestamps, amounts, c='green', edgecolors='black')

# Add a title and labels to the axes
plt.title("Payment amounts over time")
plt.xlabel("Timestamp")
plt.ylabel("Amount")

# Show the plot
plt.show()
