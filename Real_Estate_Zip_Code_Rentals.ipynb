# %% [markdown]
# <a href="https://colab.research.google.com/github/dibend/Colab/blob/main/Real_Estate_Zip_Code_Rentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension

import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import ipywidgets as widgets

plt.style.use("bmh")
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200

# Create a text box for the zip code
zip_text_box = widgets.Text(description='Zip Code:')
display(zip_text_box)

# Create a button to submit the zip
submit_button = widgets.Button(description='Submit')
submit_button.style.button_color = 'lightgreen'
display(submit_button)

def submit_callback(button):
  zip = zip_text_box.value

  # Read the CSV file
  df = pd.read_csv('https://files.zillowstatic.com/research/public_csvs/zori/Zip_zori_sm_month.csv?t=1673453726')

  # Extract the data for zip code
  df = df[df['RegionName'] == int(zip)]

  # Select the columns with dates
  df = df.loc[:, '2015-03-31':]

  # Transpose the data
  df = df.T

  # Plot the price data
  ax = df.plot()

  # Add a title
  ax.set_title(f'Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_Prices.pdf')
  files.download(f'{zip}_Rent_Prices.pdf')

  # Show the plot
  plt.show()

  # Compute the moving averages
  df_ma3 = df.rolling(3).mean()
  df_ma6 = df.rolling(6).mean()
  df_ma12 = df.rolling(12).mean()
  df_ma24 = df.rolling(24).mean()

  # Plot the 3 Month MA data
  ax = df_ma3.plot()

  # Add a title
  ax.set_title('3-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_3_Month_MA.pdf')
  files.download(f'{zip}_Rent_3_Month_MA.pdf')

  # Show the plot
  plt.show()

  # Compute the difference between the original data and the moving average
  df_diff3 = df - df_ma3

  # Plot the data
  ax = df_diff3.plot()

  # Add a title
  ax.set_title(f'Difference Between Original Data and 3-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_3_Month_MA_Diff.pdf')
  files.download(f'{zip}_Rent_3_Month_MA_Diff.pdf')

  # Show the plot
  plt.show()

  # Plot the 6 Month MA data
  ax = df_ma6.plot()

  # Add a title
  ax.set_title(f'6-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_6_Month_MA.pdf')
  files.download(f'{zip}_Rent_6_Month_MA.pdf')

  # Show the plot
  plt.show()

  # Compute the difference between the original data and the moving average
  df_diff6 = df - df_ma6

  # Plot the data
  ax = df_diff6.plot()

  # Add a title
  ax.set_title(f'Difference Between Original Data and 6-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_6_Month_MA_Diff.pdf')
  files.download(f'{zip}_Rent_6_Month_MA_Diff.pdf')

  # Show the plot
  plt.show()

  # Plot the 12 Month MA data
  ax = df_ma12.plot()

  # Add a title
  ax.set_title(f'12-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_12_Month_MA.pdf')
  files.download(f'{zip}_Rent_12_Month_MA.pdf')

  # Show the plot
  plt.show()

  # Compute the difference between the original data and the moving average
  df_diff12 = df - df_ma12

  # Plot the data
  ax = df_diff12.plot()

  # Add a title
  ax.set_title(f'Difference Between Original Data and 12-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_12_Month_MA_Diff.pdf')
  files.download(f'{zip}_Rent_12_Month_MA_Diff.pdf')

  # Show the plot
  plt.show()

  # Plot the 24 Month MA data
  ax = df_ma24.plot()

  # Add a title
  ax.set_title(f'24-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_24_Month_MA.pdf')
  files.download(f'{zip}_Rent_24_Month_MA.pdf')

  # Show the plot
  plt.show()

  # Compute the difference between the original data and the moving average
  df_diff24 = df - df_ma24

  # Plot the data
  ax = df_diff24.plot()

  # Add a title
  ax.set_title(f'Difference Between Original Data and 24-Month Moving Average of Rent Prices for Zip Code {zip}')

  # Add axis labels
  ax.set_xlabel('Date')
  ax.set_ylabel('Price')

  # Add a legend
  ax.legend(['Price'])

  plt.savefig(f'{zip}_Rent_24_Month_MA_Diff.pdf')
  files.download(f'{zip}_Rent_24_Month_MA_Diff.pdf')

  # Show the plot
  plt.show()

# Set the submit button's callback to the function we just defined
submit_button.on_click(submit_callback)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Enabling notebook extension jupyter-js-widgets/extension...
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Text(value='', description='Zip Code:')
# Button(description='Submit', style=ButtonStyle(button_color='lightgreen'))
